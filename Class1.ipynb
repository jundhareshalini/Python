# %%
print("Hello")
# Out:
# Hello

# %%
print("hello\nhow are you?")
# Out:
# hello
# how are you?

# %%
print("hi\thow are you?")
# Out:
# hi	how are you?

# %%
# data type
#string

# %%
a = "ThisIsMyFirstProgram"
print(a)
print(type(a))
print(isinstance(a,str))  # checking whether a is string or not
# Out:
# ThisIsMyFirstProgram
# <class 'str'>
# True

# %%
print(len(a))
print(min(a))
print(max(a))
print(sorted(a))
# Out:
# 20
# F
# y
# ['F', 'I', 'M', 'P', 'T', 'a', 'g', 'h', 'i', 'i', 'm', 'o', 'r', 'r', 'r', 's', 's', 's', 't', 'y']

# %%
print(a.upper())
print(a.lower())
print(a.swapcase())
# Out:
# THISISMYFIRSTPROGRAM
# thisismyfirstprogram
# tHISiSmYfIRSTpROGRAM

# %%
a = "lower"
print(a.islower())
# Out:
# True

# %%
a = "UPPER"
print(a.isupper())
# Out:
# True

# %%
a = "123"
print(a.isdigit())
# Out:
# True

# %%
a = "Shalini"
print(a.isalpha())
# Out:
# True

# %%
a = "Test123"
print(a.isalnum())
# Out:
# True

# %%
a = "Shalini"
print(a.startswith("s"))
print(a.startswith("S"))
# Out:
# False
# True

# %%
print(a.endswith("i"))
print(a.endswith("n"))
# Out:
# True
# False

# %%
a = "Sachin Tendulkar"
print(a.replace("n","@"))
print(a.replace("n","@",1)) #replace only 1st occurance
# Out:
# Sachi@ Te@dulkar
# Sachi@ Tendulkar

# %%
a = "Sachin Tendulkar"
print(a.count("a"))
# Out:
# 2

# %%
a = "Sachin Tendulkar"
print(a.split('a'))
print(a.split('a',1))
# Out:
# ['S', 'chin Tendulk', 'r']
# ['S', 'chin Tendulkar']

# %%
a = input("Enter your name:")
# Out:
# Enter your name:shalini

# %%
print(a)
# Out:
# shalini

# %%
# remove space from the string
#b = "This is todays class "
# output
#b = "Thisistodaysclass"

b = "This is todays class "
print(b.replace(" ",""))
# Out:
# Thisistodaysclass

# %%
# get input from user and check it is alphabet or not

n = input("Enter something")
print(n.isalpha())
# Out:
# Enter somethingxyz
# True
